# %%
import  pandas as pd
import numpy as np
from pymongo import MongoClient
import uuid

# %%
# Kết nối tới MongoDB
client = MongoClient('mongodb://localhost:27017/')  # Thay đổi URL nếu cần
db = client["dbduanmoi"]  # Tên cơ sở dữ liệu

# Giả sử bạn có một collection tên là 'your_collection_name'
collection = db["tbmotchill"]  # Thay đổi tên collection
# Lấy tất cả tài liệu từ collection
all_documents = list(collection.find())
# Chuyển đổi danh sách tài liệu thành DataFrame
df = pd.DataFrame(all_documents)
# Đóng kết nối
client.close()

df
# Out:
#                            _id  \
# 0     66f7f7588aa9742e25b92112
# 1     66f7f7598aa9742e25b92113
# 2     66f7f75a8aa9742e25b92114
# 3     66f7f75b8aa9742e25b92115
# 4     66f7f75c8aa9742e25b92116
# ...                        ...
# 1045  66f7fb648aa9742e25b92527
# 1046  66f7fb658aa9742e25b92528
# 1047  66f7fb658aa9742e25b92529
# 1048  66f7fb668aa9742e25b9252a
# 1049  66f7fb678aa9742e25b9252b
#
#                                               courseUrl  \
# 0       https://motchillti.net/phim/tro-khi-411156.html
# 1     https://motchillti.net/phim/sinh-vat-gyeongseo...
# 2     https://motchillti.net/phim/hoi-sat-nhan-doc-s...
# 3           https://motchillti.net/phim/mr-mcmahon.html
# 4        https://motchillti.net/phim/hoa-hoc-duong.html
# ...                                                 ...
# 1045   https://motchillti.net/phim/u-turn-quay-mat.html
# 1046  https://motchillti.net/phim/em-dep-hon-anh-sao...
# 1047  https://motchillti.net/phim/chien-doi-boc-thuo...
# 1048        https://motchillti.net/phim/beyblade-x.html
# 1049  https://motchillti.net/phim/bach-luyen-phi-tha...
#
#                             coursename               trangthai  \
# 0                              Trò Khỉ           Tập 8 Vietsub
# 1               Sinh Vật Gyeongseong 2      Full 07/07 VietSub
# 2                Hội Sát Nhân Đọc Sách            Full Vietsub
# 3                          Mr. McMahon      Full 06/06 Vietsub
# 4                        Hoa Học Đường      Full 06/06 Vietsub
# ...                                ...                     ...
# 1045                  U-Turn: Quay mặt            Full Vietsub
# 1046                Em Đẹp Hơn Ánh Sao  Full 40/40 Thuyết Minh
# 1047  Chiến Đội Bộc Thượng Boonboomger          Tập 23 VietSub
# 1048                        Beyblade X          Tập 42 VietSub
# 1049          Bách Luyện Phi Thăng Lục          Tập 79 VietSub
#
#                  daodien      thoiluong   sotap      ngonngu namsx  \
# 0          Đang cập nhật    51 phút/tập  10 Tập      Vietsub  2024
# 1         Jung Dong Yoon   65 phút/ tập   7 Tập      VietSub  2024
# 2     Carlos Alonso-Ojea        89 Phút       1      Vietsub  2023
# 3          Đang cập nhật    51 phút/tập   6 Tập      Vietsub  2024
# 4          Đang cập nhật  20 Phút / Tập   6 Tập      Vietsub  2024
# ...                  ...            ...     ...          ...   ...
# 1045       Đang cập nhật        1g 38ph       1      Vietsub  2020
# 1046       Đang cập nhật   45 phút/ tập  40 Tập  Thuyết Minh  2024
# 1047       Đang cập nhật    45 phút/tập  48 Tập      VietSub  2024
# 1048       Đang cập nhật    30 phút/tập              VietSub  2023
# 1049       Đang cập nhật    30 phút/tập              VietSub  2023
#
#           quocgia                                            theloai  \
# 0           Âu Mỹ                                  Hài Hước, Hình Sự
# 1        Hàn Quốc  Hành Động, Viễn Tưởng, Phiêu Lưu, Khoa Học, Ch...
# 2     Tây Ban Nha                                            Kinh Dị
# 3           Âu Mỹ                                           Tài Liệu
# 4        Hàn Quốc                                Tình Cảm, Học Đường
# ...           ...                                                ...
# 1045  Philippines                                            Kinh Dị
# 1046   Trung Quốc                       Tình Cảm, Chính kịch, Tâm Lý
# 1047     Nhật Bản                                          Hoạt Hình
# 1048     Nhật Bản                                          Hoạt Hình
# 1049   Trung Quốc                                          Hoạt Hình
#
#                                                    mota
# 0     Trò Khỉ - Bad Monkey (2024) Full VietSub HD Tr...
# 1     Sinh Vật Gyeongseong 2 - Gyeongseong Creature ...
# 2     Hội Sát Nhân Đọc Sách - Killer Book Club (2023...
# 3     Mr. McMahon - Mr. McMahon (2024) Full VietSub ...
# 4     Hoa Học Đường - lossom Campus (2024) Full Viet...
# ...                                                 ...
# 1045   U-Turn: Quay mặt - U-Turn (2020) Full VietSub HD
# 1046  Em Đẹp Hơn Ánh Sao - As Beautiful As You (2024...
# 1047  Chiến Đội Bộc Thượng Boonboomger - Bakuage Sen...
# 1048  Beyblade X - ベイブレードエックス (2023) Full VietSub HD...
# 1049  Bách Luyện Phi Thăng Lục - Bai Lian Feisheng L...
#
# [1050 rows x 12 columns]

# %%
df.shape
# Out:
# (1050, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         1050 non-null   object
#  1   courseUrl   1050 non-null   object
#  2   coursename  1050 non-null   object
#  3   trangthai   1050 non-null   object
#  4   daodien     1050 non-null   object
#  5   thoiluong   1050 non-null   object
#  6   sotap       1050 non-null   object
#  7   ngonngu     1050 non-null   object
#  8   namsx       1050 non-null   object
#  9   quocgia     1050 non-null   object
#  10  theloai     1050 non-null   object
#  11  mota        1050 non-null   object
# dtypes: object(12)
# memory usage: 98.6+ KB

# %%
# Giả sử df là DataFrame của bạn
# df = pd.read_csv('duongdan_toi_file.csv')  # hoặc bất kỳ phương thức nào bạn sử dụng để tạo DataFrame

# Hàm loại bỏ chữ "Tập" trong cột sotap
def remove_tap(df):
    df['sotap'] = df['sotap'].str.replace('Tập', '', regex=False)
    return df

# Gọi hàm để thực hiện
df = remove_tap(df)
df
# Out:
#                            _id  \
# 0     66f7f7588aa9742e25b92112
# 1     66f7f7598aa9742e25b92113
# 2     66f7f75a8aa9742e25b92114
# 3     66f7f75b8aa9742e25b92115
# 4     66f7f75c8aa9742e25b92116
# ...                        ...
# 1045  66f7fb648aa9742e25b92527
# 1046  66f7fb658aa9742e25b92528
# 1047  66f7fb658aa9742e25b92529
# 1048  66f7fb668aa9742e25b9252a
# 1049  66f7fb678aa9742e25b9252b
#
#                                               courseUrl  \
# 0       https://motchillti.net/phim/tro-khi-411156.html
# 1     https://motchillti.net/phim/sinh-vat-gyeongseo...
# 2     https://motchillti.net/phim/hoi-sat-nhan-doc-s...
# 3           https://motchillti.net/phim/mr-mcmahon.html
# 4        https://motchillti.net/phim/hoa-hoc-duong.html
# ...                                                 ...
# 1045   https://motchillti.net/phim/u-turn-quay-mat.html
# 1046  https://motchillti.net/phim/em-dep-hon-anh-sao...
# 1047  https://motchillti.net/phim/chien-doi-boc-thuo...
# 1048        https://motchillti.net/phim/beyblade-x.html
# 1049  https://motchillti.net/phim/bach-luyen-phi-tha...
#
#                             coursename               trangthai  \
# 0                              Trò Khỉ           Tập 8 Vietsub
# 1               Sinh Vật Gyeongseong 2      Full 07/07 VietSub
# 2                Hội Sát Nhân Đọc Sách            Full Vietsub
# 3                          Mr. McMahon      Full 06/06 Vietsub
# 4                        Hoa Học Đường      Full 06/06 Vietsub
# ...                                ...                     ...
# 1045                  U-Turn: Quay mặt            Full Vietsub
# 1046                Em Đẹp Hơn Ánh Sao  Full 40/40 Thuyết Minh
# 1047  Chiến Đội Bộc Thượng Boonboomger          Tập 23 VietSub
# 1048                        Beyblade X          Tập 42 VietSub
# 1049          Bách Luyện Phi Thăng Lục          Tập 79 VietSub
#
#                  daodien      thoiluong sotap      ngonngu namsx      quocgia  \
# 0          Đang cập nhật    51 phút/tập   10       Vietsub  2024        Âu Mỹ
# 1         Jung Dong Yoon   65 phút/ tập    7       VietSub  2024     Hàn Quốc
# 2     Carlos Alonso-Ojea        89 Phút     1      Vietsub  2023  Tây Ban Nha
# 3          Đang cập nhật    51 phút/tập    6       Vietsub  2024        Âu Mỹ
# 4          Đang cập nhật  20 Phút / Tập    6       Vietsub  2024     Hàn Quốc
# ...                  ...            ...   ...          ...   ...          ...
# 1045       Đang cập nhật        1g 38ph     1      Vietsub  2020  Philippines
# 1046       Đang cập nhật   45 phút/ tập   40   Thuyết Minh  2024   Trung Quốc
# 1047       Đang cập nhật    45 phút/tập   48       VietSub  2024     Nhật Bản
# 1048       Đang cập nhật    30 phút/tập            VietSub  2023     Nhật Bản
# 1049       Đang cập nhật    30 phút/tập            VietSub  2023   Trung Quốc
#
#                                                 theloai  \
# 0                                     Hài Hước, Hình Sự
# 1     Hành Động, Viễn Tưởng, Phiêu Lưu, Khoa Học, Ch...
# 2                                               Kinh Dị
# 3                                              Tài Liệu
# 4                                   Tình Cảm, Học Đường
# ...                                                 ...
# 1045                                            Kinh Dị
# 1046                       Tình Cảm, Chính kịch, Tâm Lý
# 1047                                          Hoạt Hình
# 1048                                          Hoạt Hình
# 1049                                          Hoạt Hình
#
#                                                    mota
# 0     Trò Khỉ - Bad Monkey (2024) Full VietSub HD Tr...
# 1     Sinh Vật Gyeongseong 2 - Gyeongseong Creature ...
# 2     Hội Sát Nhân Đọc Sách - Killer Book Club (2023...
# 3     Mr. McMahon - Mr. McMahon (2024) Full VietSub ...
# 4     Hoa Học Đường - lossom Campus (2024) Full Viet...
# ...                                                 ...
# 1045   U-Turn: Quay mặt - U-Turn (2020) Full VietSub HD
# 1046  Em Đẹp Hơn Ánh Sao - As Beautiful As You (2024...
# 1047  Chiến Đội Bộc Thượng Boonboomger - Bakuage Sen...
# 1048  Beyblade X - ベイブレードエックス (2023) Full VietSub HD...
# 1049  Bách Luyện Phi Thăng Lục - Bai Lian Feisheng L...
#
# [1050 rows x 12 columns]

# %%
# Loại bỏ chữ "Tập" trong cột sotap và chuyển đổi thành int
df['sotap'] = df['sotap'].str.replace(' Tập', '', regex=False)  # Lưu ý khoảng trắng trước Tập
df['sotap'] = pd.to_numeric(df['sotap'], errors='coerce').astype('Int64')  # Chuyển đổi sang Int64 cho phép NaN

# Chuyển đổi cột namsx thành int, giả sử namsx đã không có chữ nào
df['namsx'] = pd.to_numeric(df['namsx'], errors='coerce').astype('Int64')
# Chuyển đổi cột _id thành UUID mà không mất dữ liệu
df['_id'] = pd.to_numeric(df['_id'], errors='coerce')  # Chuyển đổi cột _id thành số, giá trị không hợp lệ sẽ là NaN

# Thay thế NaN bằng UUID mới
df['_id'] = df['_id'].apply(lambda x: uuid.uuid4() if pd.isnull(x) else x)
df.dtypes
# Out:
# _id           object
# courseUrl     object
# coursename    object
# trangthai     object
# daodien       object
# thoiluong     object
# sotap          Int64
# ngonngu       object
# namsx          Int64
# quocgia       object
# theloai       object
# mota          object
# dtype: object

# %%
df.rename(columns={'courseUrl':'duonglink', 'coursename':'tenphim'},inplace=True)
df
# Out:
#                                        _id  \
# 0     84292f84-336f-439f-9dd7-fb07c5a1001b
# 1     cf79a1ad-20ad-49d6-9cac-6f36df19ed80
# 2     61649c53-dd4b-4bd9-8ad3-07fbd5bd7e0c
# 3     dabe369b-9dd0-4a65-8ae3-5cd8efae5b87
# 4     c5cda3cf-864e-4278-8a04-bfc76349be51
# ...                                    ...
# 1045  df99e156-889b-421c-926e-d40ea3ab90b8
# 1046  b439fdf2-78c1-4b10-9c0a-1dcbd9696c4e
# 1047  3f34d737-81d0-4f30-b3a5-f1b24f4f7078
# 1048  87301561-6a69-4765-a716-e95adc31bd54
# 1049  7368ed13-1d4b-4f6d-aa97-06b7349ca167
#
#                                               duonglink  \
# 0       https://motchillti.net/phim/tro-khi-411156.html
# 1     https://motchillti.net/phim/sinh-vat-gyeongseo...
# 2     https://motchillti.net/phim/hoi-sat-nhan-doc-s...
# 3           https://motchillti.net/phim/mr-mcmahon.html
# 4        https://motchillti.net/phim/hoa-hoc-duong.html
# ...                                                 ...
# 1045   https://motchillti.net/phim/u-turn-quay-mat.html
# 1046  https://motchillti.net/phim/em-dep-hon-anh-sao...
# 1047  https://motchillti.net/phim/chien-doi-boc-thuo...
# 1048        https://motchillti.net/phim/beyblade-x.html
# 1049  https://motchillti.net/phim/bach-luyen-phi-tha...
#
#                                tenphim               trangthai  \
# 0                              Trò Khỉ           Tập 8 Vietsub
# 1               Sinh Vật Gyeongseong 2      Full 07/07 VietSub
# 2                Hội Sát Nhân Đọc Sách            Full Vietsub
# 3                          Mr. McMahon      Full 06/06 Vietsub
# 4                        Hoa Học Đường      Full 06/06 Vietsub
# ...                                ...                     ...
# 1045                  U-Turn: Quay mặt            Full Vietsub
# 1046                Em Đẹp Hơn Ánh Sao  Full 40/40 Thuyết Minh
# 1047  Chiến Đội Bộc Thượng Boonboomger          Tập 23 VietSub
# 1048                        Beyblade X          Tập 42 VietSub
# 1049          Bách Luyện Phi Thăng Lục          Tập 79 VietSub
#
#                  daodien      thoiluong  sotap      ngonngu  namsx  \
# 0          Đang cập nhật    51 phút/tập     10      Vietsub   2024
# 1         Jung Dong Yoon   65 phút/ tập      7      VietSub   2024
# 2     Carlos Alonso-Ojea        89 Phút      1      Vietsub   2023
# 3          Đang cập nhật    51 phút/tập      6      Vietsub   2024
# 4          Đang cập nhật  20 Phút / Tập      6      Vietsub   2024
# ...                  ...            ...    ...          ...    ...
# 1045       Đang cập nhật        1g 38ph      1      Vietsub   2020
# 1046       Đang cập nhật   45 phút/ tập     40  Thuyết Minh   2024
# 1047       Đang cập nhật    45 phút/tập     48      VietSub   2024
# 1048       Đang cập nhật    30 phút/tập   <NA>      VietSub   2023
# 1049       Đang cập nhật    30 phút/tập   <NA>      VietSub   2023
#
#           quocgia                                            theloai  \
# 0           Âu Mỹ                                  Hài Hước, Hình Sự
# 1        Hàn Quốc  Hành Động, Viễn Tưởng, Phiêu Lưu, Khoa Học, Ch...
# 2     Tây Ban Nha                                            Kinh Dị
# 3           Âu Mỹ                                           Tài Liệu
# 4        Hàn Quốc                                Tình Cảm, Học Đường
# ...           ...                                                ...
# 1045  Philippines                                            Kinh Dị
# 1046   Trung Quốc                       Tình Cảm, Chính kịch, Tâm Lý
# 1047     Nhật Bản                                          Hoạt Hình
# 1048     Nhật Bản                                          Hoạt Hình
# 1049   Trung Quốc                                          Hoạt Hình
#
#                                                    mota
# 0     Trò Khỉ - Bad Monkey (2024) Full VietSub HD Tr...
# 1     Sinh Vật Gyeongseong 2 - Gyeongseong Creature ...
# 2     Hội Sát Nhân Đọc Sách - Killer Book Club (2023...
# 3     Mr. McMahon - Mr. McMahon (2024) Full VietSub ...
# 4     Hoa Học Đường - lossom Campus (2024) Full Viet...
# ...                                                 ...
# 1045   U-Turn: Quay mặt - U-Turn (2020) Full VietSub HD
# 1046  Em Đẹp Hơn Ánh Sao - As Beautiful As You (2024...
# 1047  Chiến Đội Bộc Thượng Boonboomger - Bakuage Sen...
# 1048  Beyblade X - ベイブレードエックス (2023) Full VietSub HD...
# 1049  Bách Luyện Phi Thăng Lục - Bai Lian Feisheng L...
#
# [1050 rows x 12 columns]

# %%
df.describe()
# Out:
#            sotap        namsx
# count      720.0       1048.0
# mean   20.273611  2019.509542
# std    48.018238     8.155831
# min          1.0       1963.0
# 25%          1.0       2019.0
# 50%         12.0       2023.0
# 75%         24.0       2024.0
# max        560.0       2024.0

# %%
df.isnull().sum()
# Out:
# _id            0
# duonglink      0
# tenphim        0
# trangthai      0
# daodien        0
# thoiluong      0
# sotap        330
# ngonngu        0
# namsx          2
# quocgia        0
# theloai        0
# mota           0
# dtype: int64

# %%
# Thay thế giá trị NaN trong cột sotap bằng 'unknow'
df['sotap'].fillna(0, inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13264\978947153.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sotap'].fillna(0, inplace=True)

# %%
# Kiểm tra lại dữ liệu
df['sotap'].isnull().sum() # Kiểm tra số lượng NaN còn lại
# Out:
# 0

# %%
df[df['sotap'] == 0]
# Out:
#                                        _id  \
# 5     11e9b22b-eef0-4363-824d-bdcbb5cae999
# 6     10ba4a27-c14b-4630-8ec2-dda7661614b3
# 7     b3acba6a-43de-4169-941d-60e0f1ef4c3e
# 9     9f0e7dc6-17e6-4079-9732-29bf6c4f691b
# 10    06edc8cd-491e-4ac2-82bc-fb15a0f91021
# ...                                    ...
# 1017  52c3ae00-9f42-4733-84d4-186f4214f2ab
# 1018  cd6b73a6-9607-4ea6-abb1-400a62a27b14
# 1019  60c70120-06ae-4be5-906c-988401a5cacc
# 1048  87301561-6a69-4765-a716-e95adc31bd54
# 1049  7368ed13-1d4b-4f6d-aa97-06b7349ca167
#
#                                               duonglink  \
# 5          https://motchillti.net/phim/man-thu-hai.html
# 6     https://motchillti.net/phim/rong-den-vo-dai-si...
# 7       https://motchillti.net/phim/wrongful-death.html
# 9     https://motchillti.net/phim/nang-cong-chua-o-t...
# 10    https://motchillti.net/phim/truong-an-bi-van-l...
# ...                                                 ...
# 1017        https://motchillti.net/phim/good-grief.html
# 1018         https://motchillti.net/phim/thinh-the.html
# 1019  https://motchillti.net/phim/tro-lai-diem-xuat-...
# 1048        https://motchillti.net/phim/beyblade-x.html
# 1049  https://motchillti.net/phim/bach-luyen-phi-tha...
#
#                                    tenphim           trangthai  \
# 5                              Màn Thứ Hai        Full Vietsub
# 6                 Rồng Đen: Võ Đài Sinh Tử        Full Vietsub
# 7                           Wrongful Death        Full Vietsub
# 9          Nàng Công Chúa Ở Thung Lũng Gió        Full Vietsub
# 10    Trường An Bí Văn Lục: Nhiếp Ẩn Nương        Full Vietsub
# ...                                    ...                 ...
# 1017                            Good Grief        Full Vietsub
# 1018                             Thịnh Thế  Full 30/30 Vietsub
# 1019                Trở lại điểm xuất phát        Full Vietsub
# 1048                            Beyblade X      Tập 42 VietSub
# 1049              Bách Luyện Phi Thăng Lục      Tập 79 VietSub
#
#                 daodien    thoiluong  sotap  ngonngu  namsx     quocgia  \
# 5       Quentin Dupieux      85 phút      0  Vietsub   2024        Pháp
# 6      John R. Leonetti      95 phút      0  Vietsub   1997       Âu Mỹ
# 7     Vjekoslav Katušin      86 phút      0  Vietsub   2023         Đức
# 9                   宮崎駿     117 phút      0  Vietsub   1984    Nhật Bản
# 10           Vương Dĩnh      85 phút      0  Vietsub   2024  Trung Quốc
# ...                 ...          ...    ...      ...    ...         ...
# 1017        Daniel Levy    1g 40phút      0  Vietsub   2024       Âu Mỹ
# 1018      Đang cập nhật  20 phút/tập      0  Vietsub   2018  Trung Quốc
# 1019        Josh Berman    1g 43phút      0  Vietsub   2023       Âu Mỹ
# 1048      Đang cập nhật  30 phút/tập      0  VietSub   2023    Nhật Bản
# 1049      Đang cập nhật  30 phút/tập      0  VietSub   2023  Trung Quốc
#
#                     theloai                                               mota
# 5                  Hài Hước  Màn Thứ Hai - The Second Act (2024) Full VietS...
# 6     Hành Động, Viễn Tưởng  Rồng Đen: Võ Đài Sinh Tử - Mortal Kombat: Anni...
# 7             Tâm Lý, Bí ẩn  Wrongful Death - Wrongful Death (2023) Full Vi...
# 9     Phiêu Lưu, Viễn Tưởng  Nàng Công Chúa Ở Thung Lũng Gió - Nausicaä of ...
# 10      Hành Động, Cổ Trang  Trường An Bí Văn Lục: Nhiếp Ẩn Nương - A LOVE ...
# ...                     ...                                                ...
# 1017             Chính kịch  Good Grief - Good Grief (2024) Full VietSub HD...
# 1018                 Tâm Lý  Thịnh Thế - Advance Bravely (2018) Full VietSu...
# 1019     Tài Liệu, Thể Thao  Trở lại điểm xuất phát - Full Circle (2023) Fu...
# 1048              Hoạt Hình  Beyblade X - ベイブレードエックス (2023) Full VietSub HD...
# 1049              Hoạt Hình  Bách Luyện Phi Thăng Lục - Bai Lian Feisheng L...
#
# [330 rows x 12 columns]

# %%
df.dtypes
# Out:
# _id          object
# duonglink    object
# tenphim      object
# trangthai    object
# daodien      object
# thoiluong    object
# sotap         Int64
# ngonngu      object
# namsx         Int64
# quocgia      object
# theloai      object
# mota         object
# dtype: object

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Thông tin kết nối PostgreSQL
DATABASE_TYPE = 'postgresql'
DBAPI = 'psycopg2'
ENDPOINT = 'localhost'
USER = 'postgres'
PASSWORD = '123456'
PORT = 5432
DATABASE = 'dbmotchillPG'

# Tạo kết nối
engine = create_engine(f'{DATABASE_TYPE}+{DBAPI}://{USER}:{PASSWORD}@{ENDPOINT}:{PORT}/{DATABASE}')


# Lưu DataFrame vào PostgreSQL
df.to_sql('tblmotchillPG', engine, if_exists='replace', index=False)
# Out:
# 50
